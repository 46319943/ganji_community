# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
r_.cookies
# Out:
# <RequestsCookieJar[]>

# %%
r_ = requests.get('http://bj.ganji.com/')
print(r_.cookies)



r = requests.get('http://bj.ganji.com/zufang/',cookies=r_.cookies)
print(r.text)
# Out:
# <RequestsCookieJar[]>
# <!DOCTYPE html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="viewport"
# 	content="initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=0,width=device-width" />
# <title>请输入验证码 ws:59.172.176.172</title>
# <link rel="stylesheet" type="text/css"
# 	href="/new_index.css">
# <script type="text/javascript"
# 	src="/jquery-1.10.1.min.js"></script>
# </head>
# <body>
# 	<div class="pop">
# 		<p class="title">访问过于频繁，本次访问做以下验证码校验  （59.172.176.172）</p>
# 		<div class="main">
# 			<div class="code_img">
# 				<span>请在五分钟内完成验证</span>
# 			</div>
# 			<div class="code_num">
# 				<input type="button" class="btn_tj" id="btnSubmit"
# 					 value="点击按钮进行验证">
# 			</div>
# 			<div class="toast_mess" id="errmsg"></div>
# 			<div id="ISDCaptcha"></div>
# 		</div>
# 	</div>
# 	<div class="footer">
# 		©  <a href="http://www.ganji.com">ganji.com</a>
# 			</div>
# <input type="hidden" id="sessionId" value="" />
# ...

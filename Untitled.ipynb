# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
r = requests.get('https://jxjump.58.com/service?target=FCADV8oV3os7xtAj_6pMK7rUlrztK2I2XgGp_AFL66Mw0jHXZpk1zEffDjvZrKof8T9H1Etf3gzeNV-jupSXeC1kF9vXfMNHdkG41x_7k2_EqtKqjKiUdFMBckhE6YictJ71qZexEDM3yPWLxer6sNzsq2Orulw_dwCLVZtAUEnEhkw5aqSx4Uvrv63dFoqNyNhGQ4o_P0xoZ3GJyiRmP30CzK6ApDR5hWRpH8YZE29olTwTD7X5tBFg80A&pubid=0&apptype=10&psid=197020188206326886495506833&entinfo=40210814373514_0&cookie=|||b8d89b8af7aa87dbb5aa31dc95dcdb36&fzbref=0&key=&params=rankbusitime0099^desc&gjcity=bj')


print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <style type="text/css">
#     object {
#         outline: none;
#     }
# </style>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>
#     【7图】(单间出租)教工楼 专属管家 包物业费 有阳台通风好 10min到地，金顶街 - 北京赶集网</title>
# <meta name="keywords"
#       content="">
# <meta name="description"
#       content="">
# <meta name="location"
#       content="province=北京;city=北京;coord=116.4081980,39.9046670;">
# <meta http-equiv="mobile-agent" content="format=xhtml; url=//3g.ganji.com/bj__/hezu/40210814373514x.shtml?entinfo=40210814373514_0&amp;fzbref=0&amp;params=rankbusitime0099%5Edesc&amp;gjcity=bj&amp;psid=197020188206326886495506833&amp;cookie=%7C%7C%7Cb8d89b8af7aa87dbb5aa31dc95dcdb36&amp;apptype=10&amp;key=&amp;pubid=0&amp;trackkey=40210814373514_b2ddafec-d557-4357-9c77-aca29bea5668_20191119160614_1574150774181&amp;fcinfotype=gz&amp;jingxuan=1">
# ...
